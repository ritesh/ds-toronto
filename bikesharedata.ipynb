# %% [markdown]
# # Looking at Toronto Bike Share data
# This contains analyses of [https://open.toronto.ca/dataset/bike-share-toronto-ridership-data/](Toronto bike share data for 2019/20). You can fetch the data from the link above, and then unzip into a 2019 and 2020 directory to follow along. I've not included the data as they will likely not fit in the repo.
#
# I've also `pip` installed `numpy` and `pandas` and other bits and bobs via `pip install --user` . You can do this in a virtualenv, or use whatever flavour-of-the-month package manager is cool in Python (no, I'm not bitter - why do you ask?).

# %%
import numpy as np
import pandas as pd
# Remember to install this as well
import dateparser

# %%
q12019 = pd.read_csv("2019/2019-Q1.csv")

# %%
def delta(start, end):
    d = [dateparser.parse(e2) - dateparser.parse(e1) for (e1, e2) in zip(start, end)]
    return pd.Series(d)

# %%
# This doesn't quite work the way I think it does :D
q12019['deltatime'] = delta(q12019['End Time'], q12019['Start Time'])

# %%
q12019
# Out:
#         Trip Id  Subscription Id  Trip  Duration  Start Station Id  \
# 0       4581278           199751            1547              7021
# 1       4581279           294730            1112              7160
# 2       4581280           197252             589              7055
# 3       4581281           171700             259              7012
# 4       4581282           306314             281              7041
# ...         ...              ...             ...               ...
# 189058  4802537           174764             761              7048
# 189059  4802538           304393             253              7006
# 189060  4802539           212530             286              7027
# 189061  4802540           199751             677              7206
# 189062  4802541           214248             437              7076
#
#               Start Time                           Start Station Name  \
# 0       01/01/2019 00:08                           Bay St / Albert St
# ...
